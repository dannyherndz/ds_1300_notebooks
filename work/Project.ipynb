# %%
import pandas as pd
import numpy as np

# %%
mcd = pd.read_csv("../work/menu.csv")
mcd
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
mcd['Category'].value_counts()
# Out:
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Chicken & Fish        27
# Beverages             27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: Category, dtype: int64

# %%
mcd[mcd['Category']=='Coffee & Tea']
# Out:
#          Category                            Item  Serving Size  Calories  \
# 137  Coffee & Tea                Iced Tea (Small)  16 fl oz cup         0
# 138  Coffee & Tea               Iced Tea (Medium)  21 fl oz cup         0
# 139  Coffee & Tea                Iced Tea (Large)  30 fl oz cup         0
# 140  Coffee & Tea                Iced Tea (Child)  12 fl oz cup         0
# 141  Coffee & Tea               Sweet Tea (Small)  16 fl oz cup       150
# ..            ...                             ...           ...       ...
# 227  Coffee & Tea         Frappé Caramel (Medium)  16 fl oz cup       550
# 228  Coffee & Tea          Frappé Caramel (Large)  22 fl oz cup       670
# 229  Coffee & Tea   Frappé Chocolate Chip (Small)  12 fl oz cup       530
# 230  Coffee & Tea  Frappé Chocolate Chip (Medium)  16 fl oz cup       630
# 231  Coffee & Tea   Frappé Chocolate Chip (Large)  22 fl oz cup       760
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# ...

# %%
mcd['McDonalds']='Mcd'

# %%
mcd
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
mcd
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# ...

# %%
mcd = mcd.drop(columns=['Saturated Fat (% Daily Value)', 'Trans Fat', 'Dietary Fiber (% Daily Value)', 
                  'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 
                  'Iron (% Daily Value)','Cholesterol (% Daily Value)', 'Sodium', 
                  'Carbohydrates (% Daily Value)', 'Saturated Fat', 'Sodium (% Daily Value)', 'Dietary Fiber', 
                  'Total Fat (% Daily Value)', 'McDonalds', 'Cholesterol', 'Calories from Fat' ])

# %%
mcd[mcd['Item'].str.contains('Coffee')]
# Out:
#          Category                                               Item  \
# 145  Coffee & Tea                                     Coffee (Small)
# 146  Coffee & Tea                                    Coffee (Medium)
# 147  Coffee & Tea                                     Coffee (Large)
# 196  Coffee & Tea                        Regular Iced Coffee (Small)
# 197  Coffee & Tea                       Regular Iced Coffee (Medium)
# 198  Coffee & Tea                        Regular Iced Coffee (Large)
# 199  Coffee & Tea                        Caramel Iced Coffee (Small)
# 200  Coffee & Tea                       Caramel Iced Coffee (Medium)
# 201  Coffee & Tea                        Caramel Iced Coffee (Large)
# 202  Coffee & Tea                       Hazelnut Iced Coffee (Small)
# 203  Coffee & Tea                      Hazelnut Iced Coffee (Medium)
# 204  Coffee & Tea                       Hazelnut Iced Coffee (Large)
# 205  Coffee & Tea                 French Vanilla Iced Coffee (Small)
# ...

# %%
mcd = mcd[mcd['Serving Size'] == '16 fl oz cup']
mcd
# Out:
#                Category                                               Item  \
# 110           Beverages                          Coca-Cola Classic (Small)
# 114           Beverages                                  Diet Coke (Small)
# 118           Beverages                                  Dr Pepper (Small)
# 122           Beverages                             Diet Dr Pepper (Small)
# 126           Beverages                                     Sprite (Small)
# 134           Beverages                  Minute Maid Orange Juice (Medium)
# 137        Coffee & Tea                                   Iced Tea (Small)
# 141        Coffee & Tea                                  Sweet Tea (Small)
# 146        Coffee & Tea                                    Coffee (Medium)
# 147        Coffee & Tea                                     Coffee (Large)
# 149        Coffee & Tea                                     Latte (Medium)
# ...

# %%
mcd1 = mcd[mcd['Item'].str.contains('|'.join(['Latte', 'Caramel', 'Coffee', 'Mocha']))]
mcd1
# Out:
#          Category                                               Item  \
# 146  Coffee & Tea                                    Coffee (Medium)
# 147  Coffee & Tea                                     Coffee (Large)
# 149  Coffee & Tea                                     Latte (Medium)
# 152  Coffee & Tea                             Caramel Latte (Medium)
# 155  Coffee & Tea                            Hazelnut Latte (Medium)
# 158  Coffee & Tea                      French Vanilla Latte (Medium)
# 161  Coffee & Tea  Latte with Sugar Free French Vanilla Syrup (Me...
# 164  Coffee & Tea                              Nonfat Latte (Medium)
# 167  Coffee & Tea                      Nonfat Caramel Latte (Medium)
# 170  Coffee & Tea                     Nonfat Hazelnut Latte (Medium)
# 173  Coffee & Tea               Nonfat French Vanilla Latte (Medium)
# 176  Coffee & Tea  Nonfat Latte with Sugar Free French Vanilla Sy...
# 179  Coffee & Tea                                     Mocha (Medium)
# ...

# %%
mcd1.plot.bar(x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma')
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
mcd1.plot.bar(x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma', figsize=(10,10)
)
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
mcd2 = mcd1[~mcd1['Item'].str.contains('|'.join(['Iced', 'Hazelnut', 'Chocolate', 'Large', 'Vanilla']))]
mcd2
# Out:
#          Category                             Item  Serving Size  Calories  \
# 146  Coffee & Tea                  Coffee (Medium)  16 fl oz cup         0
# 149  Coffee & Tea                   Latte (Medium)  16 fl oz cup       210
# 152  Coffee & Tea           Caramel Latte (Medium)  16 fl oz cup       340
# 164  Coffee & Tea            Nonfat Latte (Medium)  16 fl oz cup       130
# 167  Coffee & Tea    Nonfat Caramel Latte (Medium)  16 fl oz cup       250
# 179  Coffee & Tea                   Mocha (Medium)  16 fl oz cup       410
# 182  Coffee & Tea  Mocha with Nonfat Milk (Medium)  16 fl oz cup       330
# 185  Coffee & Tea           Caramel Mocha (Medium)  16 fl oz cup       390
# 188  Coffee & Tea    Nonfat Caramel Mocha (Medium)  16 fl oz cup       310
# 224  Coffee & Tea            Frappé Mocha (Medium)  16 fl oz cup       550
# 227  Coffee & Tea          Frappé Caramel (Medium)  16 fl oz cup       550
#
#      Total Fat  Carbohydrates  Sugars  Protein
# ...

# %%
mcd2.plot.bar(x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma', figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
mcd2.plot.box(x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma', figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
mcd2.plot.area(stacked=False, x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma', figsize=(15,9))
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
mcd3 = mcd2[mcd2['Item'].str.contains('|'.join(['Milk', 'Cream', 'Coffee']))]
mcd3
# Out:
#          Category                             Item  Serving Size  Calories  \
# 146  Coffee & Tea                  Coffee (Medium)  16 fl oz cup         0
# 182  Coffee & Tea  Mocha with Nonfat Milk (Medium)  16 fl oz cup       330
#
#      Total Fat  Carbohydrates  Sugars  Protein
# 146        0.0              0       0        0
# 182        3.5             60      53       13

# %%
mcd3.plot.bar(x='Item', y=['Calories', 'Total Fat', 'Carbohydrates', 'Sugars', 'Protein'], colormap='plasma')
# Out:
# <AxesSubplot:xlabel='Item'>

# %%
import pandas as pd
import numpy as np

# %%
sbt = pd.read_csv("../work/starbucksdrinkmenu.csv")
sbt
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
sbt.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', 'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)'],
#       dtype='object')

# %%
sbt.drop(columns=[ 'Cholesterol (mg)', ' Dietary Fibre (g)',
       ' Sodium (mg)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
       ' Calcium (% DV) ', 'Iron (% DV) ', 'Caffeine (mg)', 'Saturated Fat (g)', 'Trans Fat (g) '], inplace=True)
sbt
# Out:
#               Beverage_category                                      Beverage  \
# 0                        Coffee                                 Brewed Coffee
# 1                        Coffee                                 Brewed Coffee
# 2                        Coffee                                 Brewed Coffee
# 3                        Coffee                                 Brewed Coffee
# 4       Classic Espresso Drinks                                   Caffè Latte
# ..                          ...                                           ...
# 237  Frappuccino® Blended Crème  Strawberries & Crème (Without Whipped Cream)
# 238  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 239  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 240  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
# 241  Frappuccino® Blended Crème          Vanilla Bean (Without Whipped Cream)
#
# ...

# %%
sbt.columns
# Out:
# Index(['Beverage_category', 'Beverage', 'Beverage_prep', 'Calories',
#        ' Total Fat (g)', ' Total Carbohydrates (g) ', ' Sugars (g)'],
#       dtype='object')

# %%
sbt[sbt['Beverage'].str.contains('Coffee', )]
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 154              Shaken Iced Beverages
# 155              Shaken Iced Beverages
# 156              Shaken Iced Beverages
# 157              Shaken Iced Beverages
# 158              Shaken Iced Beverages
# 159              Shaken Iced Beverages
# 160              Shaken Iced Beverages
# 161              Shaken Iced Beverages
# 162              Shaken Iced Beverages
# 163              Shaken Iced Beverages
# 164              Shaken Iced Beverages
# 165              Shaken Iced Beverages
# 181        Frappuccino® Blended Coffee
# 182        Frappuccino® Blended Coffee
# 183        Frappuccino® Blended Coffee
# 184        Frappuccino® Blended Coffee
# 185        Frappuccino® Blended Coffee
# 186        Frappuccino® Blended Coffee
# 187        Frappuccino® Blended Coffee
# ...

# %%
sbt1 = sbt[sbt['Beverage'].str.contains('Coffee', 'Frappuccino® Blended Crème' )]
sbt1
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 154              Shaken Iced Beverages
# 155              Shaken Iced Beverages
# 156              Shaken Iced Beverages
# 157              Shaken Iced Beverages
# 158              Shaken Iced Beverages
# 159              Shaken Iced Beverages
# 160              Shaken Iced Beverages
# 161              Shaken Iced Beverages
# 162              Shaken Iced Beverages
# 163              Shaken Iced Beverages
# 164              Shaken Iced Beverages
# 165              Shaken Iced Beverages
# 181        Frappuccino® Blended Coffee
# 182        Frappuccino® Blended Coffee
# 183        Frappuccino® Blended Coffee
# 184        Frappuccino® Blended Coffee
# 185        Frappuccino® Blended Coffee
# 186        Frappuccino® Blended Coffee
# 187        Frappuccino® Blended Coffee
# ...

# %%
sbt1[sbt1['Beverage_category'].str.contains('Coffee','Frappuccino® Blended Crème' )]
# Out:
#                      Beverage_category       Beverage       Beverage_prep  \
# 0                               Coffee  Brewed Coffee               Short
# 1                               Coffee  Brewed Coffee                Tall
# 2                               Coffee  Brewed Coffee              Grande
# 3                               Coffee  Brewed Coffee               Venti
# 181        Frappuccino® Blended Coffee         Coffee    Tall Nonfat Milk
# 182        Frappuccino® Blended Coffee         Coffee          Whole Milk
# 183        Frappuccino® Blended Coffee         Coffee             Soymilk
# 184        Frappuccino® Blended Coffee         Coffee  Grande Nonfat Milk
# 185        Frappuccino® Blended Coffee         Coffee          Whole Milk
# 186        Frappuccino® Blended Coffee         Coffee             Soymilk
# 187        Frappuccino® Blended Coffee         Coffee   Venti Nonfat Milk
# 188        Frappuccino® Blended Coffee         Coffee          Whole Milk
# ...

# %%
sbt1
# Out:
#                      Beverage_category  \
# 0                               Coffee
# 1                               Coffee
# 2                               Coffee
# 3                               Coffee
# 154              Shaken Iced Beverages
# 155              Shaken Iced Beverages
# 156              Shaken Iced Beverages
# 157              Shaken Iced Beverages
# 158              Shaken Iced Beverages
# 159              Shaken Iced Beverages
# 160              Shaken Iced Beverages
# 161              Shaken Iced Beverages
# 162              Shaken Iced Beverages
# 163              Shaken Iced Beverages
# 164              Shaken Iced Beverages
# 165              Shaken Iced Beverages
# 181        Frappuccino® Blended Coffee
# 182        Frappuccino® Blended Coffee
# 183        Frappuccino® Blended Coffee
# 184        Frappuccino® Blended Coffee
# 185        Frappuccino® Blended Coffee
# 186        Frappuccino® Blended Coffee
# 187        Frappuccino® Blended Coffee
# ...

# %%
sbt1[sbt1['Beverage_prep'].str.contains('Grande' )]
# Out:
#                      Beverage_category  \
# 2                               Coffee
# 155              Shaken Iced Beverages
# 160              Shaken Iced Beverages
# 184        Frappuccino® Blended Coffee
# 218  Frappuccino® Light Blended Coffee
#
#                                            Beverage       Beverage_prep  \
# 2                                     Brewed Coffee              Grande
# 155         Iced Brewed Coffee (With Classic Syrup)              Grande
# 160  Iced Brewed Coffee (With Milk & Classic Syrup)  Grande Nonfat Milk
# 184                                          Coffee  Grande Nonfat Milk
# 218                                          Coffee  Grande Nonfat Milk
#
#      Calories  Total Fat (g)   Total Carbohydrates (g)    Sugars (g)
# 2           5            0.1                         10            0
# 155        90            0.1                          5           21
# 160       110            0.1                         30           24
# ...

# %%
sbt1.plot.bar(x='Beverage_category')
# Out:
# <AxesSubplot:xlabel='Beverage_category'>

# %%
sbt1.plot.bar(x='Beverage_category')
# Out:
# <AxesSubplot:xlabel='Beverage_category'>

# %%
sbt1
sbt2 =sbt1.reindex([42, 10, 22, 202])
stb3 = sbt2.drop(columns=['Beverage_category', 'Sodium (mg)'])
stb4 = sbt3.rename(columns={"beverage": "Item", "Beverage_prep": "Serving Size", "Total Fat (g)": "Total Fat",
                            "Total Carbohydrates (g)": "Carbohydrates", "Sugars (g)": "Sugars"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [276], in <cell line: 3>()
#       1 sbt1
#       2 sbt2 =sbt1.reindex([42, 10, 22, 202])
# ----> 3 stb3 = sbt2.drop(columns=['Beverage_category', 'Sodium (mg)'])
#       4 stb4 = sbt3.rename(columns={"beverage": "Item", "Beverage_prep": "Serving Size", "Total Fat (g)": "Total Fat",
#       5                             "Total Carbohydrates (g)": "Carbohydrates", "Sugars (g)": "Sugars"})
#
# File ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
sbt1.plot.bar(x='Beverage_category', y=['Calories', 'Total Fat(g)', 'Total Carbohydrates(g)', 'Sugars(g)', 'Protein(g)'], colormap='plasma', figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [277], in <cell line: 1>()
# ----> 1 sbt1.plot.bar(x='Beverage_category', y=['Calories', 'Total Fat(g)', 'Total Carbohydrates(g)', 'Sugars(g)', 'Protein(g)'], colormap='plasma', figsize=(10,10))
#
# File ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/plotting/_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    1043 @Appender(
#    1044     """
#    1045     See Also
#    (...)
#    1120 @Appender(_bar_or_line_doc)
#    1121 def bar(self, x=None, y=None, **kwargs):
#    1122     """
#    1123     Vertical bar plot.
#    1124
#    (...)
#    1129     other axis represents a measured value.
#    1130     """
# -> 1131     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/plotting/_core.py:958, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
 sbt.plot.bar(x='Beverage_category', y=['Calories', 'Total Fat(g)', 'Total Carbohydrates(g)', 'Sugars(g)', 'Protein(g)'], colormap='plasma', figsize=(10,10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [278], in <cell line: 1>()
# ----> 1 sbt.plot.bar(x='Beverage_category', y=['Calories', 'Total Fat(g)', 'Total Carbohydrates(g)', 'Sugars(g)', 'Protein(g)'], colormap='plasma', figsize=(10,10))
#
# File ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/plotting/_core.py:1131, in PlotAccessor.bar(self, x, y, **kwargs)
#    1043 @Appender(
#    1044     """
#    1045     See Also
#    (...)
#    1120 @Appender(_bar_or_line_doc)
#    1121 def bar(self, x=None, y=None, **kwargs):
#    1122     """
#    1123     Vertical bar plot.
#    1124
#    (...)
#    1129     other axis represents a measured value.
#    1130     """
# -> 1131     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~/.conda/envs/ds_1300/lib/python3.9/site-packages/pandas/plotting/_core.py:958, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
